# %% [markdown]
# # Dry Eye Test

# %%
#warning
import warnings
warnings.simplefilter("ignore")

# %%
#Import libraray & modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read file
df=pd.read_csv(r'd:\Data_Analysis\Dry_Eye_Project\Dry_Eye_Dataset.csv')
df.head(5)
# Out:
#   Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 0      F   24             9.5              2             1         137/89
# 1      M   39             9.6              2             3         108/64
# 2      F   45             5.4              1             5         134/81
# 3      F   45             5.4              4             5         110/90
# 4      F   42             5.7              3             2          99/67
#
#    Heart rate  Daily steps  Physical activity  Height  ...  Smoking  \
# 0          67         3000                 31     161  ...        N
# 1          60        12000                 74     164  ...        N
# 2          95        12000                 93     179  ...        N
# 3          78        19000                 32     160  ...        N
# 4          72         4000                173     179  ...        N
#
#   Medical issue Ongoing medication Smart device before bed  \
# ...

# %%
#No of columns
df.columns
# Out:
# Index(['Gender', 'Age', 'Sleep duration', 'Sleep quality', 'Stress level',
#        'Blood pressure', 'Heart rate', 'Daily steps', 'Physical activity',
#        'Height', 'Weight', 'Sleep disorder', 'Wake up during night',
#        'Feel sleepy during day', 'Caffeine consumption', 'Alcohol consumption',
#        'Smoking', 'Medical issue', 'Ongoing medication',
#        'Smart device before bed', 'Average screen time', 'Blue-light filter',
#        'Discomfort Eye-strain', 'Redness in eye',
#        'Itchiness/Irritation in eye', 'Dry Eye Disease'],
#       dtype='object')

# %%
df.shape #26 columns & 20000 rows
# Out:
# (20000, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       20000 non-null  object
#  1   Age                          20000 non-null  int64
#  2   Sleep duration               20000 non-null  float64
#  3   Sleep quality                20000 non-null  int64
#  4   Stress level                 20000 non-null  int64
#  5   Blood pressure               20000 non-null  object
#  6   Heart rate                   20000 non-null  int64
#  7   Daily steps                  20000 non-null  int64
#  8   Physical activity            20000 non-null  int64
#  9   Height                       20000 non-null  int64
#  10  Weight                       20000 non-null  int64
#  11  Sleep disorder               20000 non-null  object
#  12  Wake up during night         20000 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Gender                         0
# Age                            0
# Sleep duration                 0
# Sleep quality                  0
# Stress level                   0
# Blood pressure                 0
# Heart rate                     0
# Daily steps                    0
# Physical activity              0
# Height                         0
# Weight                         0
# Sleep disorder                 0
# Wake up during night           0
# Feel sleepy during day         0
# Caffeine consumption           0
# Alcohol consumption            0
# Smoking                        0
# Medical issue                  0
# Ongoing medication             0
# Smart device before bed        0
# Average screen time            0
# Blue-light filter              0
# Discomfort Eye-strain          0
# Redness in eye                 0
# Itchiness/Irritation in eye    0
# Dry Eye Disease                0
# dtype: int64

# %%
df.Gender.value_counts() #10028 Male & 9972 female
# Out:
# Gender
# M    10028
# F     9972
# Name: count, dtype: int64

# %%
df.Age.describe() #Age ranging from 18 to 45
# Out:
# count    20000.000000
# mean        31.422800
# std          8.103717
# min         18.000000
# 25%         24.000000
# 50%         31.000000
# 75%         39.000000
# max         45.000000
# Name: Age, dtype: float64

# %%
df[df['Gender']=='M']['Age'].describe()
# Out:
# count    10028.000000
# mean        31.361288
# std          8.111372
# min         18.000000
# 25%         24.000000
# 50%         31.000000
# 75%         38.000000
# max         45.000000
# Name: Age, dtype: float64

# %%
Male_alocohol= df[df['Gender']=='M']['Alcohol consumption'].value_counts()
Female_alcohol= df[df['Gender']=='F']['Alcohol consumption'].value_counts()
Male_alocohol,Female_alcohol
 # from 9972 females 4963 are consuming alocohol & from 10028 Male 5046 are consuming alcohol
# Out:
# (Alcohol consumption
#  Y    5046
#  N    4982
#  Name: count, dtype: int64,
#  Alcohol consumption
#  N    5009
#  Y    4963
#  Name: count, dtype: int64)

# %%
# Plot the pie charts using Seaborn
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6))

# Pie chart for males
Male_alocohol.plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel"), ax=ax1)
ax1.set_title('Alcohol Consumption among Males')
ax1.set_ylabel('')  # Hide the y-label

# Pie chart for females
Female_alcohol.plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("pastel"), ax=ax2)
ax2.set_title('Alcohol Consumption among Females')
ax2.set_ylabel('')  # Hide the y-label

plt.show()

# %%
Male_smoker= df[df['Gender']=='M']['Smoking'].value_counts()
Female_smoker= df[df['Gender']=='F']['Smoking'].value_counts()
Male_smoker,Female_smoker
# Out:
# (Smoking
#  Y    5035
#  N    4993
#  Name: count, dtype: int64,
#  Smoking
#  N    5024
#  Y    4948
#  Name: count, dtype: int64)

# %%
# Plot the pie charts using Seaborn
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 6))

# Pie chart for males
Male_smoker.plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("flare"), ax=ax1)
ax1.set_title('Tobbaco Consumption among Males')
ax1.set_ylabel('')  # Hide the y-label

# Pie chart for females
Female_smoker.plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette("flare"), ax=ax2)
ax2.set_title('Tobbaco Consumption among Females')
ax2.set_ylabel('')  # Hide the y-label

plt.show()

# %%
#
Both_Male_smok_drink= df[(df['Gender']=='M') & (df['Alcohol consumption']=='Y') & (df['Smoking']=='Y')]
Both_female_smok_drink= df[(df['Gender']=='F') & (df['Alcohol consumption']=='Y') & (df['Smoking']=='Y')]

# %%
# Calculate the total number of males and females
total_males = df[df['Gender'] == 'M'].shape[0]
total_females = df[df['Gender'] == 'F'].shape[0]

# Calculate the number of males and females consuming both alcohol and tobacco
Both_male = df[(df['Gender'] == 'M') & (df['Smoking'] == 'Y') & (df['Alcohol consumption'] == 'Y')].shape[0]
Both_female = df[(df['Gender'] == 'F') & (df['Smoking'] == 'Y') & (df['Alcohol consumption'] == 'Y')].shape[0]

# Calculate the percentages
male_percentage = (Both_male / total_males) * 100
female_percentage = (Both_female / total_females) * 100

# Create a bar plot
labels = ['Male', 'Female']
sizes = [male_percentage, female_percentage]
colors = sns.color_palette("muted")

fig, ax = plt.subplots()
ax.bar(labels, sizes, color=colors)

ax.set_title('Percentage of Males and Females Consuming Both Alcohol and Tobacco')
ax.set_xlabel('Gender')
ax.set_ylabel('Percentage')

plt.show()

# %%
Both_female_smok_drink.head(5)
# Out:
#    Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 5       F   42             5.8              3             1         117/85
# 17      F   25             6.2              5             2         118/65
# 28      F   32             6.1              5             2         140/75
# 31      F   27             9.3              5             2          91/76
# 34      F   27             7.3              1             2         140/67
#
#     Heart rate  Daily steps  Physical activity  Height  ...  Smoking  \
# 5           79        14000                110     174  ...        Y
# 17          76         4000                 79     152  ...        Y
# 28          82        13000                153     196  ...        Y
# 31          77         9000                 36     156  ...        Y
# 34          73        11000                 65     150  ...        Y
#
#    Medical issue Ongoing medication Smart device before bed  \
# ...

# %%
df.head()
# Out:
#   Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 0      F   24             9.5              2             1         137/89
# 1      M   39             9.6              2             3         108/64
# 2      F   45             5.4              1             5         134/81
# 3      F   45             5.4              4             5         110/90
# 4      F   42             5.7              3             2          99/67
#
#    Heart rate  Daily steps  Physical activity  Height  ...  Smoking  \
# 0          67         3000                 31     161  ...        N
# 1          60        12000                 74     164  ...        N
# 2          95        12000                 93     179  ...        N
# 3          78        19000                 32     160  ...        N
# 4          72         4000                173     179  ...        N
#
#   Medical issue Ongoing medication Smart device before bed  \
# ...

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Smoking', y='Sleep duration', data=df, palette={'Y': 'red', 'N': 'blue'})

# Customize Labels and Title
plt.xlabel("Smoking Status", fontsize=12)
plt.ylabel("Sleep Duration (hours)", fontsize=12)
plt.title("Sleep Duration of Smokers vs. Non-Smokers", fontsize=14)

# Show Plot
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Alcohol consumption', y='Sleep quality', data=df, palette={'Y': 'red', 'N': 'blue'})

# Customize Labels and Title
plt.xlabel("Drinking Status", fontsize=12)
plt.ylabel("Sleep Quality", fontsize=12)
plt.title("Sleep Quality of Non Alcoholic  vs. Alcoholic", fontsize=14)

# Show Plot
plt.show()

# %%
df.head()
# Out:
#   Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 0      F   24             9.5              2             1         137/89
# 1      M   39             9.6              2             3         108/64
# 2      F   45             5.4              1             5         134/81
# 3      F   45             5.4              4             5         110/90
# 4      F   42             5.7              3             2          99/67
#
#    Heart rate  Daily steps  Physical activity  Height  ...  Smoking  \
# 0          67         3000                 31     161  ...        N
# 1          60        12000                 74     164  ...        N
# 2          95        12000                 93     179  ...        N
# 3          78        19000                 32     160  ...        N
# 4          72         4000                173     179  ...        N
#
#   Medical issue Ongoing medication Smart device before bed  \
# ...

# %%
object_col=df.select_dtypes(include="object")
df[object_col.columns] = object_col.replace({"Y": 1, "N": 0})

# %%
df["Gender"]=df["Gender"].replace({"F":1,"M":0})

# %%
### 2. Visualizing Target Distribution ###
plt.figure(figsize=(6, 4))
sns.countplot(x=df['Dry Eye Disease'], palette='coolwarm')
plt.title("Distribution of Dry Eye Disease")
plt.show()

# %%
numerical_features = ["Age", "Sleep duration", "Stress level", "Heart rate", 
                      "Daily steps", "Physical activity", "Average screen time"]
df[numerical_features].hist(figsize=(12, 8), bins=30, color='blue', edgecolor='black')
plt.suptitle("Distribution of Numerical Features", fontsize=14)
plt.show()

# %%
### 6. Dry Eye vs. Key Features ###
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
sns.boxplot(x="Dry Eye Disease", y="Age", data=df, ax=axes[0, 0])
sns.boxplot(x="Dry Eye Disease", y="Sleep duration", data=df, ax=axes[0, 1])
sns.boxplot(x="Dry Eye Disease", y="Stress level", data=df, ax=axes[0, 2])
sns.boxplot(x="Dry Eye Disease", y="Heart rate", data=df, ax=axes[1, 0])
sns.boxplot(x="Dry Eye Disease", y="Average screen time", data=df, ax=axes[1, 1])
sns.boxplot(x="Dry Eye Disease", y="Daily steps", data=df, ax=axes[1, 2])
plt.suptitle("Dry Eye vs. Key Features", fontsize=14)
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
print(df.columns)
# Out:
# Index(['Gender', 'Age', 'Sleep duration', 'Sleep quality', 'Stress level',
#        'Blood pressure', 'Heart rate', 'Daily steps', 'Physical activity',
#        'Height', 'Weight', 'Sleep disorder', 'Wake up during night',
#        'Feel sleepy during day', 'Caffeine consumption', 'Alcohol consumption',
#        'Smoking', 'Medical issue', 'Ongoing medication',
#        'Smart device before bed', 'Average screen time', 'Blue-light filter',
#        'Discomfort Eye-strain', 'Redness in eye',
#        'Itchiness/Irritation in eye', 'Dry Eye Disease'],
#       dtype='object')

# %%
df=df.drop(columns='Blood pressure')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x=df.drop(["Dry Eye Disease"],axis=1)
y=df["Dry Eye Disease"]


x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)
ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, BaggingClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier, Perceptron, SGDClassifier
from sklearn.naive_bayes import GaussianNB, BernoulliNB
from sklearn.svm import SVC, NuSVC, LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

models = {
    "Random Forest Classifier": RandomForestClassifier(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "AdaBoost Classifier": AdaBoostClassifier(),
    "Gradient Boosting Classifier": GradientBoostingClassifier(),
    "Bagging Classifier": BaggingClassifier(),
    "Extra Trees Classifier": ExtraTreesClassifier(),
    "Logistic Regression": LogisticRegression(),
    "Ridge Classifier": RidgeClassifier(),
    "Perceptron": Perceptron(),
    "SGD Classifier": SGDClassifier(),
    "Gaussian Naive Bayes": GaussianNB(),
    "Bernoulli Naive Bayes": BernoulliNB(),
    "Support Vector Classifier (SVC)": SVC(),
    "Nu-Support Vector Classifier": NuSVC(),
    "Linear SVC": LinearSVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Linear Discriminant Analysis": LinearDiscriminantAnalysis(),
    "Quadratic Discriminant Analysis": QuadraticDiscriminantAnalysis()
}

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

metrics = {
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall': [],
    'F1 Score': []
}

for name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')  # Use 'weighted' for multi-class classification
    recall = recall_score(y_test, y_pred, average='weighted')
    precision = precision_score(y_test, y_pred, average='weighted')

    metrics['Model'].append(name)
    metrics['Accuracy'].append(acc * 100)
    metrics['Precision'].append(precision * 100)
    metrics['Recall'].append(recall * 100)
    metrics['F1 Score'].append(f1 * 100)

    print(f"Model: {name}")
    print(f"Accuracy: {acc * 100:.2f}%")
    print(f"Precision: {precision * 100:.2f}%")
    print(f"Recall: {recall * 100:.2f}%")
    print(f"F1 Score: {f1 * 100:.2f}%")
    print("-" * 30)
# Out:
# Model: Random Forest Classifier
# Accuracy: 69.74%
# Precision: 67.68%
# Recall: 69.74%
# F1 Score: 64.74%
# ------------------------------
# Model: Decision Tree Classifier
# Accuracy: 56.60%
# Precision: 57.81%
# Recall: 56.60%
# F1 Score: 57.14%
# ------------------------------
# Model: AdaBoost Classifier
# Accuracy: 68.94%
# Precision: 66.82%
# Recall: 68.94%
# F1 Score: 62.15%
# ------------------------------
# Model: Gradient Boosting Classifier
# Accuracy: 70.20%
# Precision: 68.48%
# Recall: 70.20%
# F1 Score: 65.29%
# ------------------------------
# Model: Bagging Classifier
# Accuracy: 62.00%
# Precision: 61.06%
# Recall: 62.00%
# F1 Score: 61.47%
# ------------------------------
# Model: Extra Trees Classifier
# Accuracy: 69.44%
# Precision: 67.11%
# Recall: 69.44%
# F1 Score: 64.56%
# ------------------------------
# Model: Logistic Regression
# Accuracy: 69.30%
# Precision: 67.46%
# Recall: 69.30%
# F1 Score: 62.87%
# ------------------------------
# ...

# %%
#  Convert metrics dictionary to DataFrame
df_metrics = pd.DataFrame(metrics)

# Sort by accuracy in descending order
df_metrics = df_metrics.sort_values(by="Accuracy", ascending=False)

# Set style
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")
ax = sns.barplot(x="Accuracy", y="Model", data=df_metrics, palette="Blues_r")

# Add accuracy values on bars
for index, value in enumerate(df_metrics["Accuracy"]):
    ax.text(value + 0.5, index, f"{value:.2f}%", va="center", fontsize=10)

# Labels and title
plt.xlabel("Accuracy (%)")
plt.ylabel("Model")
plt.title("Model Performance: Accuracy Comparison", fontsize=14)
plt.xlim(0, 105)  # Extend limit slightly for better text visibility

plt.show()

# %% [markdown]
# #### There are 13037 Dry eye patient out of 20000
# #### out of this 6960 have Itchiness in eyes
# #### 6927 have redness in eyes
# #### There average screen time is 5.56 hrs.
# #### 6457 patients use smart device before bed.
# #### 7066 have discomfort eye strain
# #### 6517 patients wake up during night
# #### 6486 patients have sleep disorder
